# %%
import numpy as np

# Replace 'your_file.npy' with the actual path to your file
filename = 'GLCM_features.npy'

# Load the array from the .npy file
data = np.load(filename)

# Print the array
print(data)
# Out:
# [[2.72538288e+01 3.85743243e+00 2.55889802e-01 2.37380336e-02
#   9.94755334e-01 5.63494237e-04]
#  [2.70637387e+01 3.89954955e+00 2.49751644e-01 2.28805995e-02
#   9.94904648e-01 5.23521833e-04]
#  [4.57295045e+01 4.84707207e+00 2.26661716e-01 1.99467425e-02
#   9.93841757e-01 3.97872535e-04]
#  [8.85009009e+01 6.57094595e+00 1.88914335e-01 1.81064833e-02
#   9.88342151e-01 3.27844737e-04]
#  [7.00256757e+01 6.01418919e+00 1.86038889e-01 1.83444529e-02
#   9.90308006e-01 3.36518951e-04]
#  [5.46992117e+01 5.30078829e+00 2.04768424e-01 1.94510378e-02
#   9.92008365e-01 3.78342870e-04]
#  [4.34620495e+01 4.72376126e+00 2.17906967e-01 2.01806075e-02
#   9.93462711e-01 4.07256919e-04]
#  [3.81158784e+01 4.55686937e+00 2.15990386e-01 2.10160601e-02
#   9.94269989e-01 4.41674783e-04]
#  [2.31879505e+01 3.53299550e+00 2.75894836e-01 2.53785958e-02
#   9.94920058e-01 6.44073127e-04]
#  [2.25542793e+01 3.54932432e+00 2.62633509e-01 2.47891031e-02
#   9.95190463e-01 6.14499635e-04]
# ...
