# %%
import numpy as np
import os
from keras.layers import Conv3D, MaxPooling3D
from keras.layers import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape
#from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from tensorflow.keras.utils import to_categorical
from prettytable import PrettyTable
from matplotlib import pyplot as plt
import cv2
from sklearn.model_selection import KFold
import time

# %% [markdown]
# # Noise Reduction

# %%
import cv2
import os

def reduce_noise(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".mp4"):  # Assuming all files are videos
            video_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)

            # Open the video file
            cap = cv2.VideoCapture(video_path)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))

            # Create VideoWriter object
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

            # Process each frame
            for _ in range(frame_count):
                ret, frame = cap.read()
                if ret:
                    # Apply Gaussian blur for noise reduction
                    blurred_frame = cv2.GaussianBlur(frame, (5, 5), 0)
                    out.write(blurred_frame)

            # Release resources
            cap.release()
            out.release()

            print(f"Noise reduction completed for {filename}")

# Example usage:
input_folder = "D:\\FINAL MAJOR20-2\\Dataset1.0"
output_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
reduce_noise(input_folder, output_folder)
# Out:
# Noise reduction completed for a.mp4
# Noise reduction completed for bye.mp4
# Noise reduction completed for can.mp4
# Noise reduction completed for cat.mp4
# Noise reduction completed for demo.mp4
# Noise reduction completed for dog.mp4
# Noise reduction completed for hello.mp4
# Noise reduction completed for here.mp4
# Noise reduction completed for is.mp4
# Noise reduction completed for lips.mp4
# Noise reduction completed for my.mp4
# Noise reduction completed for read.mp4
# Noise reduction completed for you.mp4

# %% [markdown]
# # Converting to Frames

# %%
import os
import cv2

def extract_frames(video_folder, output_folder, num_frames=8):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each video file in the folder
    for filename in os.listdir(video_folder):
        if filename.endswith(".mp4") or filename.endswith(".avi"):
            video_path = os.path.join(video_folder, filename)
            video_name = os.path.splitext(filename)[0]

            # Create a subfolder for each video
            video_output_folder = os.path.join(output_folder, video_name)
            if not os.path.exists(video_output_folder):
                os.makedirs(video_output_folder)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get the total number of frames in the video
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Calculate the frame interval to get exactly num_frames frames
            frame_interval = max(1, total_frames // num_frames)

            frame_count = 0

            # Read and process each frame
            while(cap.isOpened() and frame_count < num_frames):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame
                output_frame_path = os.path.join(video_output_folder, f"{video_name}_frame_{frame_count}.jpg")
                cv2.imwrite(output_frame_path, frame)

                frame_count += 1

                # Move to the next frame based on the calculated interval
                cap.set(cv2.CAP_PROP_POS_FRAMES, frame_count * frame_interval)

            cap.release()

# Example usage:
video_dataset_folder = "D:\\FINAL MAJOR20-2\\Noise reduction\\output"
output_frames_folder = "D:\\FINAL MAJOR20-2\\Frames"
extract_frames(video_dataset_folder, output_frames_folder, num_frames=8)

# %% [markdown]
# # Converting Normal Frames into GLCM

# %%
import os
import cv2
import numpy as np
from skimage.feature import graycomatrix, graycoprops

def glcm_noise_reduction(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Compute the GLCM of the grayscale image
    glcm = graycomatrix(gray, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])

    # Compute the mean of the GLCM
    mean_glcm = np.mean(glcm)

    # Subtract the mean from the original image to reduce noise
    reduced_noise_image = gray - mean_glcm

    return reduced_noise_image

# Specify the directory containing the folders with frames
root_dir = "D:\\FINAL MAJOR20-2\\Frames"

# Create a new folder to save all the noise-reduced images
new_root_dir = "D:\\FINAL MAJOR20-2\\output_denoised_image_folder"

# Loop over each folder (video)
for folder in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder)
    new_folder_path = os.path.join(new_root_dir, folder)
    os.makedirs(new_folder_path, exist_ok=True)

    # Loop over each image (frame) in the folder
    for frame in os.listdir(folder_path):
        frame_path = os.path.join(folder_path, frame)

        # Read the image
        image = cv2.imread(frame_path)

        # Apply GLCM noise reduction
        reduced_noise_image = glcm_noise_reduction(image)

        # Save the noise-reduced image in the new folder
        cv2.imwrite(os.path.join(new_folder_path, frame), reduced_noise_image)

print('Noise reduction completed.')
# Out:
# Noise reduction completed.

# %% [markdown]
# # GLCM_lstm

# %%
import os
import imageio
import numpy as np
from skimage.feature import graycomatrix, graycoprops
from skimage import io
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten
from tensorflow.keras.callbacks import Callback
from sklearn.model_selection import train_test_split

# Constants
IMAGE_SIZE = (96, 72)
NUM_CLASSES = 17
PATCH_SIZE = 35

# Load dataset
dataset_dir = "D:/FINAL MAJOR20-2/GLCM-LSTM/ownDataset/output_denoised_image_folder"
class_folders = os.listdir(dataset_dir)
classes = {class_name: i for i, class_name in enumerate(class_folders)}
num_samples = sum(len(os.listdir(os.path.join(dataset_dir, class_name))) for class_name in class_folders)

# %%
from sklearn.model_selection import KFold
import time

# Define number of folds
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize arrays to store features and labels
X = np.zeros((num_samples, 6))  # 6 GLCM properties per patch
y = np.zeros((num_samples, NUM_CLASSES))

class AccuracyCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch+1}/{self.params['epochs']}, Accuracy: {logs['accuracy']}, Val Accuracy: {logs['val_accuracy']}")


# Extract GLCM features for each image frame
index = 0
for class_name in class_folders:
    class_dir = os.path.join(dataset_dir, class_name)
    for image_file in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_file)
        image = imageio.imread(image_path)
        # Resize image to required size
        #image = cv2.resize(image, IMAGE_SIZE)
        # Compute GLCM
        GLCM = graycomatrix(image, [1], [0, np.pi/4, np.pi/2, 3*np.pi/4])
        features = []
        for prop in ['contrast', 'dissimilarity', 'homogeneity', 'energy', 'correlation', 'ASM']:
            features.append(graycoprops(GLCM, prop)[0, 0])
        X[index] = np.array(features)
        y[index, classes[class_name]] = 1
        index += 1

# Save GLCM features (optional)
#np.save('GLCM_features.npy', X)

train_accuracy_list = []
val_accuracy_list = []
comp_times = []
fold_index = 1

# Build LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(1, 6)))  # Input shape is (1, 6) for each patch
model.add(Dense(NUM_CLASSES, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

#startTime
start_time = time.time()
for train_index, val_index in kfold.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Reshape input data for LSTM
    X_train = np.expand_dims(X_train, axis=1)
    X_val = np.expand_dims(X_val, axis=1)

    # Train the model
    start_fold_time = time.time()
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), callbacks=[AccuracyCallback()])
    end_fold_time = time.time()
    comp_times.append(end_fold_time - start_fold_time)

    train_accuracy_list.append(history.history['accuracy'][-1])
    val_accuracy_list.append(history.history['val_accuracy'][-1])

    # Save the model
    model.save(f'GLCM_LSTM_fold{fold_index}.h5')
    fold_index += 1
# Track end time
end_time = time.time()
# Calculate average training and validation accuracy
avg_train_accuracy = np.mean(train_accuracy_list)
avg_val_accuracy = np.mean(val_accuracy_list)

print(f'Average Training Accuracy: {avg_train_accuracy * 100:.2f}%')
print(f'Average Validation Accuracy: {avg_val_accuracy * 100:.2f}%')
print("Average Training Time:", np.mean(comp_times))
print("Total Training Time:", end_time - start_time)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_11428\1877795115.py:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_path)
# Epoch 1/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.8492 - accuracy: 0.0729Epoch 1/100, Accuracy: 0.07983193546533585, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 2s 73ms/step - loss: 2.8441 - accuracy: 0.0798 - val_loss: 2.8370 - val_accuracy: 0.1000
# Epoch 2/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.8082 - accuracy: 0.1250Epoch 2/100, Accuracy: 0.11764705926179886, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 16ms/step - loss: 2.8129 - accuracy: 0.1176 - val_loss: 2.8438 - val_accuracy: 0.0833
# Epoch 3/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.7982 - accuracy: 0.1198Epoch 3/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 17ms/step - loss: 2.8000 - accuracy: 0.1218 - val_loss: 2.8497 - val_accuracy: 0.0833
# Epoch 4/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7848 - accuracy: 0.1339Epoch 4/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.06666667014360428
# 8/8 [==============================] - 0s 13ms/step - loss: 2.7886 - accuracy: 0.1303 - val_loss: 2.8520 - val_accuracy: 0.0667
# Epoch 5/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7825 - accuracy: 0.1161Epoch 5/100, Accuracy: 0.11344537883996964, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 14ms/step - loss: 2.7838 - accuracy: 0.1134 - val_loss: 2.8564 - val_accuracy: 0.1000
# Epoch 6/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7758 - accuracy: 0.1295Epoch 6/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 13ms/step - loss: 2.7766 - accuracy: 0.1261 - val_loss: 2.8510 - val_accuracy: 0.1000
# Epoch 7/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7728 - accuracy: 0.1562Epoch 7/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.7726 - accuracy: 0.1513 - val_loss: 2.8440 - val_accuracy: 0.1167
# Epoch 8/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.8035 - accuracy: 0.1250Epoch 8/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 12ms/step - loss: 2.7669 - accuracy: 0.1345 - val_loss: 2.8402 - val_accuracy: 0.1000
# Epoch 9/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7659 - accuracy: 0.1473Epoch 9/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 14ms/step - loss: 2.7629 - accuracy: 0.1471 - val_loss: 2.8363 - val_accuracy: 0.1167
# Epoch 10/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7581 - accuracy: 0.1387Epoch 10/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.7581 - accuracy: 0.1387 - val_loss: 2.8332 - val_accuracy: 0.1167
# Epoch 11/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7507 - accuracy: 0.1295Epoch 11/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 20ms/step - loss: 2.7553 - accuracy: 0.1218 - val_loss: 2.8315 - val_accuracy: 0.0833
# Epoch 12/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.7428 - accuracy: 0.1063Epoch 12/100, Accuracy: 0.11344537883996964, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 19ms/step - loss: 2.7498 - accuracy: 0.1134 - val_loss: 2.8337 - val_accuracy: 0.0833
# Epoch 13/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7453 - accuracy: 0.1295Epoch 13/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.7456 - accuracy: 0.1303 - val_loss: 2.8266 - val_accuracy: 0.1167
# Epoch 14/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.7288 - accuracy: 0.1458Epoch 14/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 20ms/step - loss: 2.7405 - accuracy: 0.1471 - val_loss: 2.8241 - val_accuracy: 0.1167
# Epoch 15/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7361 - accuracy: 0.1471Epoch 15/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 16ms/step - loss: 2.7361 - accuracy: 0.1471 - val_loss: 2.8183 - val_accuracy: 0.1000
# Epoch 16/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7056 - accuracy: 0.2500Epoch 16/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.7304 - accuracy: 0.1387 - val_loss: 2.8144 - val_accuracy: 0.1000
# Epoch 17/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7714 - accuracy: 0.1250Epoch 17/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.7258 - accuracy: 0.1303 - val_loss: 2.8115 - val_accuracy: 0.1167
# Epoch 18/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7169 - accuracy: 0.1384Epoch 18/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.06666667014360428
# 8/8 [==============================] - 0s 15ms/step - loss: 2.7232 - accuracy: 0.1345 - val_loss: 2.8090 - val_accuracy: 0.0667
# Epoch 19/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6893 - accuracy: 0.1562Epoch 19/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.7193 - accuracy: 0.1303 - val_loss: 2.8041 - val_accuracy: 0.1167
# Epoch 20/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7167 - accuracy: 0.1513Epoch 20/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 12ms/step - loss: 2.7167 - accuracy: 0.1513 - val_loss: 2.7989 - val_accuracy: 0.1000
# Epoch 21/100
# 8/8 [==============================] - ETA: 0s - loss: 2.7130 - accuracy: 0.1387Epoch 21/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 13ms/step - loss: 2.7130 - accuracy: 0.1387 - val_loss: 2.7989 - val_accuracy: 0.0833
# Epoch 22/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.7165 - accuracy: 0.1302Epoch 22/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 17ms/step - loss: 2.7094 - accuracy: 0.1471 - val_loss: 2.7949 - val_accuracy: 0.1167
# Epoch 23/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.7162 - accuracy: 0.1607Epoch 23/100, Accuracy: 0.16386555135250092, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 16ms/step - loss: 2.7056 - accuracy: 0.1639 - val_loss: 2.7974 - val_accuracy: 0.1333
# Epoch 24/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6995 - accuracy: 0.1652Epoch 24/100, Accuracy: 0.15546219050884247, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.7041 - accuracy: 0.1555 - val_loss: 2.7930 - val_accuracy: 0.1167
# Epoch 25/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6635 - accuracy: 0.1562Epoch 25/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6979 - accuracy: 0.1471 - val_loss: 2.7892 - val_accuracy: 0.1333
# Epoch 26/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6991 - accuracy: 0.1339Epoch 26/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6959 - accuracy: 0.1471 - val_loss: 2.7846 - val_accuracy: 0.1167
# Epoch 27/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6164 - accuracy: 0.1250Epoch 27/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6918 - accuracy: 0.1345 - val_loss: 2.7862 - val_accuracy: 0.1333
# Epoch 28/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6967 - accuracy: 0.1198Epoch 28/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6892 - accuracy: 0.1387 - val_loss: 2.7875 - val_accuracy: 0.0833
# Epoch 29/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6776 - accuracy: 0.1875Epoch 29/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6880 - accuracy: 0.1387 - val_loss: 2.7892 - val_accuracy: 0.0833
# Epoch 30/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.6866 - accuracy: 0.1437Epoch 30/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6858 - accuracy: 0.1387 - val_loss: 2.7852 - val_accuracy: 0.0833
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6827 - accuracy: 0.1387Epoch 31/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 14ms/step - loss: 2.6827 - accuracy: 0.1387 - val_loss: 2.7851 - val_accuracy: 0.0833
# Epoch 32/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6815 - accuracy: 0.1518Epoch 32/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6796 - accuracy: 0.1471 - val_loss: 2.7851 - val_accuracy: 0.1167
# Epoch 33/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6750 - accuracy: 0.0938Epoch 33/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6793 - accuracy: 0.1471 - val_loss: 2.7857 - val_accuracy: 0.1167
# Epoch 34/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6689 - accuracy: 0.1510Epoch 34/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6778 - accuracy: 0.1513 - val_loss: 2.7879 - val_accuracy: 0.0833
# Epoch 35/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6808 - accuracy: 0.1406Epoch 35/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6744 - accuracy: 0.1513 - val_loss: 2.7832 - val_accuracy: 0.1167
# Epoch 36/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6689 - accuracy: 0.1406Epoch 36/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6708 - accuracy: 0.1345 - val_loss: 2.7802 - val_accuracy: 0.1333
# Epoch 37/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6694 - accuracy: 0.1429Epoch 37/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6716 - accuracy: 0.1387 - val_loss: 2.7815 - val_accuracy: 0.1167
# Epoch 38/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6815 - accuracy: 0.1562Epoch 38/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6684 - accuracy: 0.1387 - val_loss: 2.7810 - val_accuracy: 0.1167
# Epoch 39/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6618 - accuracy: 0.1384Epoch 39/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6655 - accuracy: 0.1471 - val_loss: 2.7840 - val_accuracy: 0.1167
# Epoch 40/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7302 - accuracy: 0.0625Epoch 40/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6654 - accuracy: 0.1261 - val_loss: 2.7849 - val_accuracy: 0.1333
# Epoch 41/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6924 - accuracy: 0.1875Epoch 41/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6624 - accuracy: 0.1261 - val_loss: 2.7797 - val_accuracy: 0.1167
# Epoch 42/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6617 - accuracy: 0.1875Epoch 42/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6602 - accuracy: 0.1261 - val_loss: 2.7745 - val_accuracy: 0.1000
# Epoch 43/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6926 - accuracy: 0.0312Epoch 43/100, Accuracy: 0.11764705926179886, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6594 - accuracy: 0.1176 - val_loss: 2.7730 - val_accuracy: 0.0833
# Epoch 44/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6701 - accuracy: 0.1042Epoch 44/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6591 - accuracy: 0.1387 - val_loss: 2.7751 - val_accuracy: 0.1000
# Epoch 45/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6751 - accuracy: 0.1250Epoch 45/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6578 - accuracy: 0.1345 - val_loss: 2.7749 - val_accuracy: 0.1000
# Epoch 46/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6319 - accuracy: 0.1562Epoch 46/100, Accuracy: 0.11344537883996964, Val Accuracy: 0.06666667014360428
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6572 - accuracy: 0.1134 - val_loss: 2.7786 - val_accuracy: 0.0667
# Epoch 47/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6607 - accuracy: 0.1071Epoch 47/100, Accuracy: 0.11764705926179886, Val Accuracy: 0.06666667014360428
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6554 - accuracy: 0.1176 - val_loss: 2.7772 - val_accuracy: 0.0667
# Epoch 48/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6506 - accuracy: 0.1205Epoch 48/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6549 - accuracy: 0.1218 - val_loss: 2.7759 - val_accuracy: 0.1000
# Epoch 49/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6567 - accuracy: 0.1250Epoch 49/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6537 - accuracy: 0.1218 - val_loss: 2.7785 - val_accuracy: 0.1000
# Epoch 50/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6488 - accuracy: 0.1161Epoch 50/100, Accuracy: 0.11764705926179886, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6505 - accuracy: 0.1176 - val_loss: 2.7809 - val_accuracy: 0.1000
# Epoch 51/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6576 - accuracy: 0.1295Epoch 51/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6501 - accuracy: 0.1303 - val_loss: 2.7790 - val_accuracy: 0.1000
# Epoch 52/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6461 - accuracy: 0.1250Epoch 52/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6496 - accuracy: 0.1261 - val_loss: 2.7786 - val_accuracy: 0.1000
# Epoch 53/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5267 - accuracy: 0.2500Epoch 53/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6454 - accuracy: 0.1345 - val_loss: 2.7866 - val_accuracy: 0.1167
# Epoch 54/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6378 - accuracy: 0.1384Epoch 54/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6483 - accuracy: 0.1303 - val_loss: 2.7818 - val_accuracy: 0.1000
# Epoch 55/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6556 - accuracy: 0.1250Epoch 55/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6448 - accuracy: 0.1387 - val_loss: 2.7794 - val_accuracy: 0.1000
# Epoch 56/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6449 - accuracy: 0.1518Epoch 56/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6443 - accuracy: 0.1471 - val_loss: 2.7846 - val_accuracy: 0.1167
# Epoch 57/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6447 - accuracy: 0.1303Epoch 57/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6447 - accuracy: 0.1303 - val_loss: 2.7809 - val_accuracy: 0.1167
# Epoch 58/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6521 - accuracy: 0.1302Epoch 58/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6409 - accuracy: 0.1429 - val_loss: 2.7739 - val_accuracy: 0.1167
# Epoch 59/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6392 - accuracy: 0.0938Epoch 59/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6398 - accuracy: 0.1218 - val_loss: 2.7697 - val_accuracy: 0.1167
# Epoch 60/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6590 - accuracy: 0.1094Epoch 60/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6404 - accuracy: 0.1261 - val_loss: 2.7660 - val_accuracy: 0.1333
# Epoch 61/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7239 - accuracy: 0.0938Epoch 61/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6386 - accuracy: 0.1303 - val_loss: 2.7709 - val_accuracy: 0.1000
# Epoch 62/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6126 - accuracy: 0.1250Epoch 62/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6372 - accuracy: 0.1261 - val_loss: 2.7695 - val_accuracy: 0.0833
# Epoch 63/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6604 - accuracy: 0.0938Epoch 63/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6372 - accuracy: 0.1218 - val_loss: 2.7771 - val_accuracy: 0.0833
# Epoch 64/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6296 - accuracy: 0.1875Epoch 64/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6352 - accuracy: 0.1218 - val_loss: 2.7796 - val_accuracy: 0.0833
# Epoch 65/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6355 - accuracy: 0.1261Epoch 65/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6355 - accuracy: 0.1261 - val_loss: 2.7813 - val_accuracy: 0.1000
# Epoch 66/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5055 - accuracy: 0.2188Epoch 66/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6336 - accuracy: 0.1303 - val_loss: 2.7796 - val_accuracy: 0.1333
# Epoch 67/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7328 - accuracy: 0.0625Epoch 67/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6321 - accuracy: 0.1471 - val_loss: 2.7730 - val_accuracy: 0.1000
# Epoch 68/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7339 - accuracy: 0.0625Epoch 68/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6312 - accuracy: 0.1303 - val_loss: 2.7685 - val_accuracy: 0.1000
# Epoch 69/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.6190 - accuracy: 0.1437Epoch 69/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.06666667014360428
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6309 - accuracy: 0.1218 - val_loss: 2.7745 - val_accuracy: 0.0667
# Epoch 70/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7130 - accuracy: 0.1562Epoch 70/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 9ms/step - loss: 2.6295 - accuracy: 0.1261 - val_loss: 2.7693 - val_accuracy: 0.0833
# Epoch 71/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6025 - accuracy: 0.1198Epoch 71/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6296 - accuracy: 0.1303 - val_loss: 2.7680 - val_accuracy: 0.1167
# Epoch 72/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7031 - accuracy: 0.0625Epoch 72/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6294 - accuracy: 0.1429 - val_loss: 2.7693 - val_accuracy: 0.1167
# Epoch 73/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6394 - accuracy: 0.0938Epoch 73/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6261 - accuracy: 0.1303 - val_loss: 2.7726 - val_accuracy: 0.1167
# Epoch 74/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5379 - accuracy: 0.1562Epoch 74/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6262 - accuracy: 0.1345 - val_loss: 2.7726 - val_accuracy: 0.1000
# Epoch 75/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6225 - accuracy: 0.1429Epoch 75/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6247 - accuracy: 0.1387 - val_loss: 2.7704 - val_accuracy: 0.1167
# Epoch 76/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6250 - accuracy: 0.1261Epoch 76/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6250 - accuracy: 0.1261 - val_loss: 2.7693 - val_accuracy: 0.1000
# Epoch 77/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4714 - accuracy: 0.1875Epoch 77/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6222 - accuracy: 0.1218 - val_loss: 2.7704 - val_accuracy: 0.1000
# Epoch 78/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5824 - accuracy: 0.0938Epoch 78/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6228 - accuracy: 0.1345 - val_loss: 2.7641 - val_accuracy: 0.1000
# Epoch 79/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6248 - accuracy: 0.1384Epoch 79/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6215 - accuracy: 0.1345 - val_loss: 2.7648 - val_accuracy: 0.1167
# Epoch 80/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6933 - accuracy: 0.0938Epoch 80/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6213 - accuracy: 0.1345 - val_loss: 2.7695 - val_accuracy: 0.1167
# Epoch 81/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6248 - accuracy: 0.1429Epoch 81/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 14ms/step - loss: 2.6208 - accuracy: 0.1429 - val_loss: 2.7759 - val_accuracy: 0.0833
# Epoch 82/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6282 - accuracy: 0.1250Epoch 82/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6180 - accuracy: 0.1345 - val_loss: 2.7699 - val_accuracy: 0.1000
# Epoch 83/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6028 - accuracy: 0.0625Epoch 83/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6190 - accuracy: 0.1218 - val_loss: 2.7695 - val_accuracy: 0.1333
# Epoch 84/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6325 - accuracy: 0.1406Epoch 84/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 19ms/step - loss: 2.6178 - accuracy: 0.1345 - val_loss: 2.7697 - val_accuracy: 0.1000
# Epoch 85/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6472 - accuracy: 0.0625Epoch 85/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6194 - accuracy: 0.1345 - val_loss: 2.7674 - val_accuracy: 0.1000
# Epoch 86/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7426 - accuracy: 0.1875Epoch 86/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6169 - accuracy: 0.1303 - val_loss: 2.7666 - val_accuracy: 0.1167
# Epoch 87/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6078 - accuracy: 0.1205Epoch 87/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6141 - accuracy: 0.1218 - val_loss: 2.7645 - val_accuracy: 0.0833
# Epoch 88/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6010 - accuracy: 0.1161Epoch 88/100, Accuracy: 0.11344537883996964, Val Accuracy: 0.0833333358168602
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6121 - accuracy: 0.1134 - val_loss: 2.7641 - val_accuracy: 0.0833
# Epoch 89/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6168 - accuracy: 0.1250Epoch 89/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6124 - accuracy: 0.1345 - val_loss: 2.7626 - val_accuracy: 0.1000
# Epoch 90/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6183 - accuracy: 0.1295Epoch 90/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6114 - accuracy: 0.1345 - val_loss: 2.7642 - val_accuracy: 0.1000
# Epoch 91/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.5983 - accuracy: 0.1250Epoch 91/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6121 - accuracy: 0.1429 - val_loss: 2.7637 - val_accuracy: 0.1167
# Epoch 92/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.6783 - accuracy: 0.1437Epoch 92/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6105 - accuracy: 0.1429 - val_loss: 2.7653 - val_accuracy: 0.1000
# Epoch 93/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6173 - accuracy: 0.1295Epoch 93/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6101 - accuracy: 0.1303 - val_loss: 2.7642 - val_accuracy: 0.1167
# Epoch 94/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.6268 - accuracy: 0.1250Epoch 94/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6089 - accuracy: 0.1261 - val_loss: 2.7628 - val_accuracy: 0.1167
# Epoch 95/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5815 - accuracy: 0.1406Epoch 95/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6082 - accuracy: 0.1345 - val_loss: 2.7565 - val_accuracy: 0.1167
# Epoch 96/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6553 - accuracy: 0.0938Epoch 96/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6054 - accuracy: 0.1387 - val_loss: 2.7561 - val_accuracy: 0.1333
# Epoch 97/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4956 - accuracy: 0.1875Epoch 97/100, Accuracy: 0.15546219050884247, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6054 - accuracy: 0.1555 - val_loss: 2.7521 - val_accuracy: 0.1333
# Epoch 98/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.5784 - accuracy: 0.1437Epoch 98/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 23ms/step - loss: 2.6053 - accuracy: 0.1345 - val_loss: 2.7502 - val_accuracy: 0.1000
# Epoch 99/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6035 - accuracy: 0.1345Epoch 99/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6035 - accuracy: 0.1345 - val_loss: 2.7566 - val_accuracy: 0.1000
# Epoch 100/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6012 - accuracy: 0.1303Epoch 100/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6012 - accuracy: 0.1303 - val_loss: 2.7585 - val_accuracy: 0.1000
# Epoch 1/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6601 - accuracy: 0.1161Epoch 1/100, Accuracy: 0.11764705926179886, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6502 - accuracy: 0.1176 - val_loss: 2.5657 - val_accuracy: 0.1333
# Epoch 2/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5909 - accuracy: 0.1562Epoch 2/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6456 - accuracy: 0.1345 - val_loss: 2.5843 - val_accuracy: 0.1500
# Epoch 3/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6339 - accuracy: 0.1384Epoch 3/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 15ms/step - loss: 2.6357 - accuracy: 0.1345 - val_loss: 2.5942 - val_accuracy: 0.1833
# Epoch 4/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6161 - accuracy: 0.1510Epoch 4/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.1666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6337 - accuracy: 0.1471 - val_loss: 2.6035 - val_accuracy: 0.1667
# Epoch 5/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6293 - accuracy: 0.1429Epoch 5/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6293 - accuracy: 0.1429 - val_loss: 2.6063 - val_accuracy: 0.1833
# Epoch 6/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.7220 - accuracy: 0.1875Epoch 6/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6277 - accuracy: 0.1471 - val_loss: 2.6047 - val_accuracy: 0.1167
# Epoch 7/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5246 - accuracy: 0.0938Epoch 7/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6266 - accuracy: 0.1345 - val_loss: 2.6049 - val_accuracy: 0.1167
# Epoch 8/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5406 - accuracy: 0.2188Epoch 8/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.20000000298023224
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6227 - accuracy: 0.1345 - val_loss: 2.5987 - val_accuracy: 0.2000
# Epoch 9/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6029 - accuracy: 0.1406Epoch 9/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.21666666865348816
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6223 - accuracy: 0.1513 - val_loss: 2.6042 - val_accuracy: 0.2167
# Epoch 10/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6134 - accuracy: 0.1384Epoch 10/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6205 - accuracy: 0.1387 - val_loss: 2.6057 - val_accuracy: 0.1833
# Epoch 11/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4641 - accuracy: 0.1562Epoch 11/100, Accuracy: 0.12184873968362808, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 9ms/step - loss: 2.6174 - accuracy: 0.1218 - val_loss: 2.6160 - val_accuracy: 0.1000
# Epoch 12/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5224 - accuracy: 0.2188Epoch 12/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6198 - accuracy: 0.1303 - val_loss: 2.6296 - val_accuracy: 0.1333
# Epoch 13/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6210 - accuracy: 0.1458Epoch 13/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 16ms/step - loss: 2.6160 - accuracy: 0.1345 - val_loss: 2.6214 - val_accuracy: 0.1333
# Epoch 14/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5507 - accuracy: 0.2188Epoch 14/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6168 - accuracy: 0.1387 - val_loss: 2.6130 - val_accuracy: 0.1167
# Epoch 15/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6201 - accuracy: 0.1302Epoch 15/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6152 - accuracy: 0.1345 - val_loss: 2.6092 - val_accuracy: 0.1833
# Epoch 16/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.5958 - accuracy: 0.1437    Epoch 16/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6136 - accuracy: 0.1471 - val_loss: 2.6179 - val_accuracy: 0.1833
# Epoch 17/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6261 - accuracy: 0.1406Epoch 17/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.1666666716337204
# 8/8 [==============================] - 0s 17ms/step - loss: 2.6142 - accuracy: 0.1387 - val_loss: 2.6179 - val_accuracy: 0.1667
# Epoch 18/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6108 - accuracy: 0.1345Epoch 18/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.1666666716337204
# 8/8 [==============================] - 0s 14ms/step - loss: 2.6108 - accuracy: 0.1345 - val_loss: 2.6179 - val_accuracy: 0.1667
# Epoch 19/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.6125 - accuracy: 0.1339Epoch 19/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6094 - accuracy: 0.1345 - val_loss: 2.6131 - val_accuracy: 0.1833
# Epoch 20/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.5988 - accuracy: 0.1375Epoch 20/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 19ms/step - loss: 2.6093 - accuracy: 0.1471 - val_loss: 2.6066 - val_accuracy: 0.1833
# Epoch 21/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5860 - accuracy: 0.1250Epoch 21/100, Accuracy: 0.13865546882152557, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6092 - accuracy: 0.1387 - val_loss: 2.6105 - val_accuracy: 0.1500
# Epoch 22/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5805 - accuracy: 0.1562Epoch 22/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6060 - accuracy: 0.1303 - val_loss: 2.6103 - val_accuracy: 0.1500
# Epoch 23/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6057 - accuracy: 0.1429Epoch 23/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.1666666716337204
# 8/8 [==============================] - 0s 14ms/step - loss: 2.6057 - accuracy: 0.1429 - val_loss: 2.6188 - val_accuracy: 0.1667
# Epoch 24/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4940 - accuracy: 0.2188Epoch 24/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6049 - accuracy: 0.1429 - val_loss: 2.6168 - val_accuracy: 0.1500
# Epoch 25/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6024 - accuracy: 0.1513Epoch 25/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 12ms/step - loss: 2.6024 - accuracy: 0.1513 - val_loss: 2.6160 - val_accuracy: 0.1333
# Epoch 26/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6962 - accuracy: 0.1562Epoch 26/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 11ms/step - loss: 2.6024 - accuracy: 0.1471 - val_loss: 2.6210 - val_accuracy: 0.1333
# Epoch 27/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5920 - accuracy: 0.0625Epoch 27/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 10ms/step - loss: 2.6010 - accuracy: 0.1429 - val_loss: 2.6208 - val_accuracy: 0.1500
# Epoch 28/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5906 - accuracy: 0.1458Epoch 28/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 18ms/step - loss: 2.5990 - accuracy: 0.1429 - val_loss: 2.6155 - val_accuracy: 0.1333
# Epoch 29/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5931 - accuracy: 0.1473Epoch 29/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.20000000298023224
# 8/8 [==============================] - 0s 17ms/step - loss: 2.5982 - accuracy: 0.1471 - val_loss: 2.6115 - val_accuracy: 0.2000
# Epoch 30/100
# 8/8 [==============================] - ETA: 0s - loss: 2.6006 - accuracy: 0.1471Epoch 30/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 13ms/step - loss: 2.6006 - accuracy: 0.1471 - val_loss: 2.6014 - val_accuracy: 0.1833
# Epoch 31/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5967 - accuracy: 0.1429Epoch 31/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 12ms/step - loss: 2.5967 - accuracy: 0.1429 - val_loss: 2.6171 - val_accuracy: 0.1167
# Epoch 32/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5855 - accuracy: 0.1354Epoch 32/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 15ms/step - loss: 2.5953 - accuracy: 0.1303 - val_loss: 2.6210 - val_accuracy: 0.1167
# Epoch 33/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6430 - accuracy: 0.1250Epoch 33/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 10ms/step - loss: 2.5968 - accuracy: 0.1429 - val_loss: 2.6221 - val_accuracy: 0.1000
# Epoch 34/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5932 - accuracy: 0.1562Epoch 34/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 14ms/step - loss: 2.5949 - accuracy: 0.1513 - val_loss: 2.6205 - val_accuracy: 0.1333
# Epoch 35/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.6280 - accuracy: 0.1510Epoch 35/100, Accuracy: 0.17226891219615936, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 15ms/step - loss: 2.5951 - accuracy: 0.1723 - val_loss: 2.6163 - val_accuracy: 0.1333
# Epoch 36/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5741 - accuracy: 0.1823Epoch 36/100, Accuracy: 0.1596638709306717, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 17ms/step - loss: 2.5945 - accuracy: 0.1597 - val_loss: 2.6100 - val_accuracy: 0.1500
# Epoch 37/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5842 - accuracy: 0.1562Epoch 37/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 14ms/step - loss: 2.5920 - accuracy: 0.1513 - val_loss: 2.6112 - val_accuracy: 0.1833
# Epoch 38/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5973 - accuracy: 0.1302Epoch 38/100, Accuracy: 0.1596638709306717, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 17ms/step - loss: 2.5913 - accuracy: 0.1597 - val_loss: 2.6123 - val_accuracy: 0.1500
# Epoch 39/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.6032 - accuracy: 0.1500Epoch 39/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 22ms/step - loss: 2.5916 - accuracy: 0.1513 - val_loss: 2.6118 - val_accuracy: 0.1333
# Epoch 40/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5836 - accuracy: 0.1607Epoch 40/100, Accuracy: 0.16386555135250092, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 13ms/step - loss: 2.5902 - accuracy: 0.1639 - val_loss: 2.6051 - val_accuracy: 0.1833
# Epoch 41/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5902 - accuracy: 0.1406Epoch 41/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 16ms/step - loss: 2.5880 - accuracy: 0.1471 - val_loss: 2.6146 - val_accuracy: 0.1167
# Epoch 42/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5954 - accuracy: 0.1302Epoch 42/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.5892 - accuracy: 0.1261 - val_loss: 2.6118 - val_accuracy: 0.1167
# Epoch 43/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5880 - accuracy: 0.1261Epoch 43/100, Accuracy: 0.1260504275560379, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.5880 - accuracy: 0.1261 - val_loss: 2.6089 - val_accuracy: 0.1167
# Epoch 44/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5883 - accuracy: 0.1429Epoch 44/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 17ms/step - loss: 2.5874 - accuracy: 0.1471 - val_loss: 2.6115 - val_accuracy: 0.1000
# Epoch 45/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5866 - accuracy: 0.1429Epoch 45/100, Accuracy: 0.1428571492433548, Val Accuracy: 0.10000000149011612
# 8/8 [==============================] - 0s 14ms/step - loss: 2.5866 - accuracy: 0.1429 - val_loss: 2.6071 - val_accuracy: 0.1000
# Epoch 46/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5926 - accuracy: 0.1607Epoch 46/100, Accuracy: 0.16386555135250092, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 15ms/step - loss: 2.5852 - accuracy: 0.1639 - val_loss: 2.6063 - val_accuracy: 0.1333
# Epoch 47/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6398 - accuracy: 0.1250Epoch 47/100, Accuracy: 0.16386555135250092, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 11ms/step - loss: 2.5841 - accuracy: 0.1639 - val_loss: 2.6106 - val_accuracy: 0.1167
# Epoch 48/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5866 - accuracy: 0.1597Epoch 48/100, Accuracy: 0.1596638709306717, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 12ms/step - loss: 2.5866 - accuracy: 0.1597 - val_loss: 2.6226 - val_accuracy: 0.1167
# Epoch 49/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5933 - accuracy: 0.1354Epoch 49/100, Accuracy: 0.15126051008701324, Val Accuracy: 0.13333334028720856
# 8/8 [==============================] - 0s 17ms/step - loss: 2.5829 - accuracy: 0.1513 - val_loss: 2.6135 - val_accuracy: 0.1333
# Epoch 50/100
# 8/8 [==============================] - ETA: 0s - loss: 2.5807 - accuracy: 0.1681Epoch 50/100, Accuracy: 0.16806723177433014, Val Accuracy: 0.11666666716337204
# 8/8 [==============================] - 0s 13ms/step - loss: 2.5807 - accuracy: 0.1681 - val_loss: 2.6076 - val_accuracy: 0.1167
# Epoch 51/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5822 - accuracy: 0.1518Epoch 51/100, Accuracy: 0.15546219050884247, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 16ms/step - loss: 2.5830 - accuracy: 0.1555 - val_loss: 2.5970 - val_accuracy: 0.1833
# Epoch 52/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5330 - accuracy: 0.1562Epoch 52/100, Accuracy: 0.1596638709306717, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 11ms/step - loss: 2.5821 - accuracy: 0.1597 - val_loss: 2.6001 - val_accuracy: 0.1500
# Epoch 53/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3802 - accuracy: 0.1562Epoch 53/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 11ms/step - loss: 2.5804 - accuracy: 0.1471 - val_loss: 2.6076 - val_accuracy: 0.1500
# Epoch 54/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.6813 - accuracy: 0.1250Epoch 54/100, Accuracy: 0.13445378839969635, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 10ms/step - loss: 2.5794 - accuracy: 0.1345 - val_loss: 2.6147 - val_accuracy: 0.1500
# Epoch 55/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5039 - accuracy: 0.1562Epoch 55/100, Accuracy: 0.14705882966518402, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 11ms/step - loss: 2.5773 - accuracy: 0.1471 - val_loss: 2.6056 - val_accuracy: 0.1500
# Epoch 56/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5902 - accuracy: 0.1652Epoch 56/100, Accuracy: 0.16386555135250092, Val Accuracy: 0.18333333730697632
# 8/8 [==============================] - 0s 14ms/step - loss: 2.5779 - accuracy: 0.1639 - val_loss: 2.5958 - val_accuracy: 0.1833
# Epoch 57/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.5837 - accuracy: 0.1518Epoch 57/100, Accuracy: 0.15546219050884247, Val Accuracy: 0.1666666716337204
# 8/8 [==============================] - 0s 21ms/step - loss: 2.5801 - accuracy: 0.1555 - val_loss: 2.6034 - val_accuracy: 0.1667
# Epoch 58/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3917 - accuracy: 0.2500Epoch 58/100, Accuracy: 0.15546219050884247, Val Accuracy: 0.15000000596046448
# 8/8 [==============================] - 0s 12ms/step - loss: 2.5767 - accuracy: 0.1555 - val_loss: 2.6098 - val_accuracy: 0.1500
# Epoch 59/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.5851 - accuracy: 0.1354Epoch 59/100, Accuracy: 0.13025210797786713, Val Accuracy: 0.1666666716337204
# 8/8 [==============================] - 0s 16ms/step - loss: 2.5756 - accuracy: 0.1303 - val_loss: 2.5994 - val_accuracy: 0.1667
# Epoch 60/100
# ...
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4031 - accuracy: 0.2301 - val_loss: 2.4454 - val_accuracy: 0.2203
# Epoch 49/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.4097 - accuracy: 0.2098Epoch 49/100, Accuracy: 0.2092050164937973, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 16ms/step - loss: 2.4001 - accuracy: 0.2092 - val_loss: 2.4502 - val_accuracy: 0.2034
# Epoch 50/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3939 - accuracy: 0.2455Epoch 50/100, Accuracy: 0.23849372565746307, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 16ms/step - loss: 2.4009 - accuracy: 0.2385 - val_loss: 2.4506 - val_accuracy: 0.2203
# Epoch 51/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.4093 - accuracy: 0.2188Epoch 51/100, Accuracy: 0.22175732254981995, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 13ms/step - loss: 2.4033 - accuracy: 0.2218 - val_loss: 2.4526 - val_accuracy: 0.2034
# Epoch 52/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.4480 - accuracy: 0.2031Epoch 52/100, Accuracy: 0.20083682239055634, Val Accuracy: 0.1525423675775528
# 8/8 [==============================] - 0s 18ms/step - loss: 2.4085 - accuracy: 0.2008 - val_loss: 2.4471 - val_accuracy: 0.1525
# Epoch 53/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.4328 - accuracy: 0.1875Epoch 53/100, Accuracy: 0.21338912844657898, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 19ms/step - loss: 2.4091 - accuracy: 0.2134 - val_loss: 2.4668 - val_accuracy: 0.2203
# Epoch 54/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4086 - accuracy: 0.2812Epoch 54/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 10ms/step - loss: 2.4069 - accuracy: 0.2301 - val_loss: 2.4483 - val_accuracy: 0.1864
# Epoch 55/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4772 - accuracy: 0.2500Epoch 55/100, Accuracy: 0.20502091944217682, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3956 - accuracy: 0.2050 - val_loss: 2.4702 - val_accuracy: 0.2203
# Epoch 56/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4701 - accuracy: 0.1875Epoch 56/100, Accuracy: 0.22175732254981995, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 11ms/step - loss: 2.4104 - accuracy: 0.2218 - val_loss: 2.4604 - val_accuracy: 0.2034
# Epoch 57/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.1013 - accuracy: 0.3438Epoch 57/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3985 - accuracy: 0.2301 - val_loss: 2.4700 - val_accuracy: 0.2034
# Epoch 58/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.2861 - accuracy: 0.1562Epoch 58/100, Accuracy: 0.20502091944217682, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3988 - accuracy: 0.2050 - val_loss: 2.4659 - val_accuracy: 0.2034
# Epoch 59/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3945 - accuracy: 0.2259Epoch 59/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 14ms/step - loss: 2.3945 - accuracy: 0.2259 - val_loss: 2.4720 - val_accuracy: 0.2034
# Epoch 60/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3926 - accuracy: 0.2321Epoch 60/100, Accuracy: 0.2343096286058426, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3973 - accuracy: 0.2343 - val_loss: 2.4653 - val_accuracy: 0.1864
# Epoch 61/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3945 - accuracy: 0.2259Epoch 61/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.16949152946472168
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3945 - accuracy: 0.2259 - val_loss: 2.4643 - val_accuracy: 0.1695
# Epoch 62/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4123 - accuracy: 0.1875Epoch 62/100, Accuracy: 0.22175732254981995, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3950 - accuracy: 0.2218 - val_loss: 2.4585 - val_accuracy: 0.1864
# Epoch 63/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.4052 - accuracy: 0.2250Epoch 63/100, Accuracy: 0.21338912844657898, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3972 - accuracy: 0.2134 - val_loss: 2.4407 - val_accuracy: 0.2203
# Epoch 64/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5082 - accuracy: 0.2188Epoch 64/100, Accuracy: 0.22175732254981995, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3959 - accuracy: 0.2218 - val_loss: 2.4465 - val_accuracy: 0.2203
# Epoch 65/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.2256 - accuracy: 0.2812Epoch 65/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3942 - accuracy: 0.2259 - val_loss: 2.4564 - val_accuracy: 0.2203
# Epoch 66/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3953 - accuracy: 0.2218Epoch 66/100, Accuracy: 0.22175732254981995, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3953 - accuracy: 0.2218 - val_loss: 2.4535 - val_accuracy: 0.2034
# Epoch 67/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5339 - accuracy: 0.0625Epoch 67/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3930 - accuracy: 0.2176 - val_loss: 2.4688 - val_accuracy: 0.2203
# Epoch 68/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.2907 - accuracy: 0.3438Epoch 68/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3928 - accuracy: 0.2301 - val_loss: 2.4569 - val_accuracy: 0.1864
# Epoch 69/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3917 - accuracy: 0.2176Epoch 69/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3917 - accuracy: 0.2176 - val_loss: 2.4508 - val_accuracy: 0.2034
# Epoch 70/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3937 - accuracy: 0.2232Epoch 70/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 19ms/step - loss: 2.3908 - accuracy: 0.2259 - val_loss: 2.4594 - val_accuracy: 0.2034
# Epoch 71/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.3692 - accuracy: 0.2448Epoch 71/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 15ms/step - loss: 2.3901 - accuracy: 0.2176 - val_loss: 2.4520 - val_accuracy: 0.1864
# Epoch 72/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3431 - accuracy: 0.2500Epoch 72/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3895 - accuracy: 0.2301 - val_loss: 2.4672 - val_accuracy: 0.2203
# Epoch 73/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.4125 - accuracy: 0.2438Epoch 73/100, Accuracy: 0.23849372565746307, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 18ms/step - loss: 2.3923 - accuracy: 0.2385 - val_loss: 2.4694 - val_accuracy: 0.2034
# Epoch 74/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3885 - accuracy: 0.2385Epoch 74/100, Accuracy: 0.23849372565746307, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3885 - accuracy: 0.2385 - val_loss: 2.4646 - val_accuracy: 0.2034
# Epoch 75/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5275 - accuracy: 0.1562Epoch 75/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3875 - accuracy: 0.2301 - val_loss: 2.4655 - val_accuracy: 0.2203
# Epoch 76/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.2755 - accuracy: 0.2500Epoch 76/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3860 - accuracy: 0.2176 - val_loss: 2.4583 - val_accuracy: 0.2034
# Epoch 77/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.4199 - accuracy: 0.2188Epoch 77/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 16ms/step - loss: 2.3861 - accuracy: 0.2259 - val_loss: 2.4691 - val_accuracy: 0.2203
# Epoch 78/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.5380 - accuracy: 0.1875Epoch 78/100, Accuracy: 0.21338912844657898, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3872 - accuracy: 0.2134 - val_loss: 2.4614 - val_accuracy: 0.2203
# Epoch 79/100
# 5/8 [=================>............] - ETA: 0s - loss: 2.4148 - accuracy: 0.1937Epoch 79/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 22ms/step - loss: 2.3881 - accuracy: 0.2176 - val_loss: 2.4757 - val_accuracy: 0.2203
# Epoch 80/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.1347 - accuracy: 0.2500Epoch 80/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3857 - accuracy: 0.2259 - val_loss: 2.4635 - val_accuracy: 0.2034
# Epoch 81/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.3654 - accuracy: 0.2552Epoch 81/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 16ms/step - loss: 2.3845 - accuracy: 0.2301 - val_loss: 2.4696 - val_accuracy: 0.2203
# Epoch 82/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4628 - accuracy: 0.2500Epoch 82/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3862 - accuracy: 0.2301 - val_loss: 2.4629 - val_accuracy: 0.2034
# Epoch 83/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3884 - accuracy: 0.2176Epoch 83/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3884 - accuracy: 0.2176 - val_loss: 2.4584 - val_accuracy: 0.2034
# Epoch 84/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3339 - accuracy: 0.2188Epoch 84/100, Accuracy: 0.2343096286058426, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3889 - accuracy: 0.2343 - val_loss: 2.4805 - val_accuracy: 0.2203
# Epoch 85/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3709 - accuracy: 0.2366Epoch 85/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 15ms/step - loss: 2.3882 - accuracy: 0.2259 - val_loss: 2.4698 - val_accuracy: 0.2034
# Epoch 86/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3758 - accuracy: 0.2455Epoch 86/100, Accuracy: 0.24686191976070404, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 21ms/step - loss: 2.3791 - accuracy: 0.2469 - val_loss: 2.4784 - val_accuracy: 0.2203
# Epoch 87/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3941 - accuracy: 0.1875Epoch 87/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3876 - accuracy: 0.2259 - val_loss: 2.4729 - val_accuracy: 0.2034
# Epoch 88/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3348 - accuracy: 0.2500Epoch 88/100, Accuracy: 0.2343096286058426, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3818 - accuracy: 0.2343 - val_loss: 2.4753 - val_accuracy: 0.1864
# Epoch 89/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3818 - accuracy: 0.2385Epoch 89/100, Accuracy: 0.23849372565746307, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3818 - accuracy: 0.2385 - val_loss: 2.4724 - val_accuracy: 0.2203
# Epoch 90/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.4533 - accuracy: 0.3125Epoch 90/100, Accuracy: 0.23849372565746307, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 11ms/step - loss: 2.3802 - accuracy: 0.2385 - val_loss: 2.4699 - val_accuracy: 0.2034
# Epoch 91/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3855 - accuracy: 0.2092Epoch 91/100, Accuracy: 0.2092050164937973, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 13ms/step - loss: 2.3855 - accuracy: 0.2092 - val_loss: 2.4620 - val_accuracy: 0.2034
# Epoch 92/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.3558 - accuracy: 0.2240Epoch 92/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 17ms/step - loss: 2.3874 - accuracy: 0.2176 - val_loss: 2.4671 - val_accuracy: 0.2034
# Epoch 93/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3467 - accuracy: 0.1875Epoch 93/100, Accuracy: 0.21757322549819946, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3811 - accuracy: 0.2176 - val_loss: 2.4592 - val_accuracy: 0.1864
# Epoch 94/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.2808 - accuracy: 0.2500Epoch 94/100, Accuracy: 0.22594141960144043, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3776 - accuracy: 0.2259 - val_loss: 2.4730 - val_accuracy: 0.2203
# Epoch 95/100
# 4/8 [==============>...............] - ETA: 0s - loss: 2.4280 - accuracy: 0.2188Epoch 95/100, Accuracy: 0.2301255166530609, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 16ms/step - loss: 2.3804 - accuracy: 0.2301 - val_loss: 2.4747 - val_accuracy: 0.2034
# Epoch 96/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.3838 - accuracy: 0.3125Epoch 96/100, Accuracy: 0.2343096286058426, Val Accuracy: 0.18644067645072937
# 8/8 [==============================] - 0s 10ms/step - loss: 2.3774 - accuracy: 0.2343 - val_loss: 2.4710 - val_accuracy: 0.1864
# Epoch 97/100
# 8/8 [==============================] - ETA: 0s - loss: 2.3862 - accuracy: 0.2050Epoch 97/100, Accuracy: 0.20502091944217682, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 12ms/step - loss: 2.3862 - accuracy: 0.2050 - val_loss: 2.4778 - val_accuracy: 0.2034
# Epoch 98/100
# 1/8 [==>...........................] - ETA: 0s - loss: 2.2494 - accuracy: 0.2188Epoch 98/100, Accuracy: 0.17991632223129272, Val Accuracy: 0.1355932205915451
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3774 - accuracy: 0.1799 - val_loss: 2.4706 - val_accuracy: 0.1356
# Epoch 99/100
# 6/8 [=====================>........] - ETA: 0s - loss: 2.4097 - accuracy: 0.1875Epoch 99/100, Accuracy: 0.1882845163345337, Val Accuracy: 0.20338982343673706
# 8/8 [==============================] - 0s 16ms/step - loss: 2.3805 - accuracy: 0.1883 - val_loss: 2.4730 - val_accuracy: 0.2034
# Epoch 100/100
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3703 - accuracy: 0.2411Epoch 100/100, Accuracy: 0.2343096286058426, Val Accuracy: 0.22033898532390594
# 8/8 [==============================] - 0s 16ms/step - loss: 2.3761 - accuracy: 0.2343 - val_loss: 2.4721 - val_accuracy: 0.2203
# Average Training Accuracy: 17.78%
# Average Validation Accuracy: 13.44%
# Average Training Time: 10.947630643844604
# Total Training Time: 54.96536350250244

# %%
# Calculate average training and validation accuracy
avg_train_accuracy = np.mean(train_accuracy_list)
avg_val_accuracy = np.mean(val_accuracy_list)

print(f'Average Training Accuracy: {avg_train_accuracy * 100:.2f}%')
print(f'Average Validation Accuracy: {avg_val_accuracy * 100:.2f}%')
# Out:
# Average Training Accuracy: 17.78%
# Average Validation Accuracy: 13.44%

# %% [markdown]
# # Training accuracy

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # ROC CURVE

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have trained your model
# Get predictions on validation data
y_pred = model.predict(X_val)
y_true = y_val

# Convert y_true to single label format
y_true_single = np.argmax(y_true, axis=1)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASSES):
    fpr[i], tpr[i], _ = roc_curve((y_true_single == i).astype(int), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curve
plt.figure(figsize=(10, 8))
for i in range(NUM_CLASSES):
    plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guessing')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
from keras.models import load_model

# Initialize arrays to store predictions and true labels
y_true_all = []
y_pred_all = []

fold_index = 1
for train_index, val_index in kfold.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Reshape input data for LSTM
    X_train = np.expand_dims(X_train, axis=1)
    X_val = np.expand_dims(X_val, axis=1)

    # Load the trained model for the current fold
    model = load_model(f'GLCM_LSTM_fold{fold_index}.h5')

    # Get predictions on validation data
    y_pred = model.predict(X_val)
    y_true = y_val

    # Convert y_true to single label format
    y_true_single = np.argmax(y_true, axis=1)
    y_pred_single = np.argmax(y_pred, axis=1)

    y_true_all.extend(y_true_single)
    y_pred_all.extend(y_pred_single)

    fold_index += 1

# Calculate confusion matrix
cm = confusion_matrix(y_true_all, y_pred_all)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(np.arange(NUM_CLASSES))
plt.yticks(np.arange(NUM_CLASSES))
for i in range(NUM_CLASSES):
    for j in range(NUM_CLASSES):
        plt.text(j, i, cm[i, j], ha='center', va='center', color='white')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000258AE8D4160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002587F2C0E50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
from sklearn.metrics import precision_recall_fscore_support
from prettytable import PrettyTable
import pandas as pd
import numpy as np

# Initialize lists to store metrics for each fold and each class
train_precisions = [[] for _ in range(NUM_CLASSES)]
train_recalls = [[] for _ in range(NUM_CLASSES)]
train_f1_scores = [[] for _ in range(NUM_CLASSES)]
train_supports = [[] for _ in range(NUM_CLASSES)]
val_precisions = [[] for _ in range(NUM_CLASSES)]
val_recalls = [[] for _ in range(NUM_CLASSES)]
val_f1_scores = [[] for _ in range(NUM_CLASSES)]
val_supports = [[] for _ in range(NUM_CLASSES)]

fold_index = 1
for train_index, val_index in kfold.split(X):
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]

    # Reshape input data for LSTM
    X_train = np.expand_dims(X_train, axis=1)
    X_val = np.expand_dims(X_val, axis=1)

    # Load the trained model for the current fold
    model = load_model(f'GLCM_LSTM_fold{fold_index}.h5')

    # Get predictions on training and validation data
    train_predictions = model.predict(X_train)
    val_predictions = model.predict(X_val)

    # Convert predictions to class labels
    train_pred_labels = np.argmax(train_predictions, axis=1)
    val_pred_labels = np.argmax(val_predictions, axis=1)

    # Calculate metrics for training and validation data for each class
    for class_idx in range(NUM_CLASSES):
        train_precision, train_recall, train_f1_score, _ = precision_recall_fscore_support(
            np.argmax(y_train, axis=1), train_pred_labels, labels=[class_idx], average='macro', zero_division=1)
        val_precision, val_recall, val_f1_score, _ = precision_recall_fscore_support(
            np.argmax(y_val, axis=1), val_pred_labels, labels=[class_idx], average='macro', zero_division=1)

        train_precisions[class_idx].append(train_precision)
        train_recalls[class_idx].append(train_recall)
        train_f1_scores[class_idx].append(train_f1_score)

        val_precisions[class_idx].append(val_precision)
        val_recalls[class_idx].append(val_recall)
        val_f1_scores[class_idx].append(val_f1_score)

        # Calculate support based on actual number of instances
        train_support = np.sum(np.argmax(y_train, axis=1) == class_idx)
        val_support = np.sum(np.argmax(y_val, axis=1) == class_idx)

        train_supports[class_idx].append(train_support)
        val_supports[class_idx].append(val_support)

    fold_index += 1



# Calculate average metrics for each class
avg_train_precisions = [np.nanmean([prec for prec in precisions]) for precisions in train_precisions]
avg_train_recalls = [np.nanmean([rec for rec in recalls]) for recalls in train_recalls]
avg_train_f1_scores = [np.nanmean([f1 for f1 in f1_scores]) for f1_scores in train_f1_scores]
avg_train_supports = [np.mean([sup for sup in supports if not np.isnan(sup)]) for supports in train_supports]

avg_val_precisions = [np.nanmean([prec for prec in precisions]) for precisions in val_precisions]
avg_val_recalls = [np.nanmean([rec for rec in recalls]) for recalls in val_recalls]
avg_val_f1_scores = [np.nanmean([f1 for f1 in f1_scores]) for f1_scores in val_f1_scores]
avg_val_supports = [np.mean([sup for sup in supports if not np.isnan(sup)]) for supports in val_supports]




# Create PrettyTable for average training metrics
train_table = PrettyTable()
train_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]
for class_idx in range(NUM_CLASSES):
    train_table.add_row([class_idx, avg_train_precisions[class_idx], avg_train_recalls[class_idx],
                         avg_train_f1_scores[class_idx], avg_train_supports[class_idx]])

# Create PrettyTable for average validation metrics
val_table = PrettyTable()
val_table.field_names = ["Class", "Precision", "Recall", "F1 Score", "Support"]
for class_idx in range(NUM_CLASSES):
    val_table.add_row([class_idx, avg_val_precisions[class_idx], avg_val_recalls[class_idx],
                       avg_val_f1_scores[class_idx], avg_val_supports[class_idx]])

# Print tables
print("Average Training Metrics:")
print(train_table)
print("\nAverage Validation Metrics:")
print(val_table)

# Create DataFrames for average training and validation metrics
train_df = pd.DataFrame({
    'Class': range(NUM_CLASSES),
    'Precision': avg_train_precisions,
    'Recall': avg_train_recalls,
    'F1 Score': avg_train_f1_scores,
    'Support': avg_train_supports
})

val_df = pd.DataFrame({
    'Class': range(NUM_CLASSES),
    'Precision': avg_val_precisions,
    'Recall': avg_val_recalls,
    'F1 Score': avg_val_f1_scores,
    'Support': avg_val_supports
})

# Concatenate DataFrames
combined_df = pd.concat([train_df, val_df], ignore_index=True)

# Save combined DataFrame to an Excel sheet
combined_excel_path = 'OWNDATASET_AFTERKFOLD.xlsx'
combined_df.to_excel(combined_excel_path, index=False)

print(f"Average metrics saved to {combined_excel_path}")
# Out:
# Average Training Metrics:
# +-------+---------------------+----------------------+----------------------+---------+
# | Class |      Precision      |        Recall        |       F1 Score       | Support |
# +-------+---------------------+----------------------+----------------------+---------+
# |   0   |         0.85        | 0.03076923076923077  | 0.03809523809523809  |   12.8  |
# |   1   |  0.7303030303030302 | 0.07999999999999999  | 0.06519607843137255  |   14.4  |
# |   2   |         1.0         |         0.0          |         0.0          |   11.2  |
# |   3   | 0.18715102096522515 |  0.6302339181286549  | 0.28712106146806365  |   17.6  |
# |   4   |  0.5205276705276706 | 0.17802197802197803  | 0.13007792207792207  |   12.8  |
# |   5   |         0.8         |         0.0          |         0.0          |   14.4  |
# |   6   |         0.7         | 0.15153846153846154  |  0.1922051282051282  |   11.2  |
# |   7   |  0.6714285714285714 | 0.21818181818181817  | 0.23768115942028983  |   11.2  |
# |   8   |  0.6666666666666667 | 0.03636363636363636  | 0.047058823529411764 |   11.2  |
# |   9   | 0.17529330572808832 |  0.3388345864661654  | 0.21629145784749365  |   16.0  |
# |   10  |  0.4137931034482759 | 0.026666666666666665 | 0.01818181818181818  |   12.8  |
# |   11  |  0.4220853858784893 | 0.29694570135746606  | 0.22901565013894984  |   14.4  |
# |   12  |         1.0         |         0.0          |         0.0          |   14.4  |
# |   13  | 0.11584895456081896 |  0.2723175586023883  | 0.15567921538070792  |   17.6  |
# |   14  | 0.42444444444444446 | 0.14974358974358976  | 0.17908902691511386  |   14.4  |
# |   15  | 0.44663382594417084 | 0.06928104575163399  | 0.05529542920847268  |   16.0  |
# |   16  |  0.2625327304834978 |  0.4242156862745098  |  0.3218764759624837  |   16.0  |
# +-------+---------------------+----------------------+----------------------+---------+
#
# Average Validation Metrics:
# +-------+---------------------+---------------------+----------------------+---------+
# | Class |      Precision      |        Recall       |       F1 Score       | Support |
# +-------+---------------------+---------------------+----------------------+---------+
# |   0   |         0.8         |         0.0         |         0.0          |   3.2   |
# |   1   |         0.6         |         0.0         |         0.0          |   3.6   |
# |   2   |         1.0         |         0.0         |         0.0          |   2.8   |
# |   3   |  0.1953672058935217 |  0.6809523809523809 | 0.28335403726708075  |   4.4   |
# |   4   |         0.4         |         0.0         |         0.0          |   3.2   |
# |   5   |         0.8         |         0.0         |         0.0          |   3.6   |
# |   6   |         0.8         |         0.1         | 0.13333333333333333  |   2.8   |
# |   7   |  0.7333333333333333 | 0.13333333333333333 | 0.13333333333333333  |   2.8   |
# |   8   |         0.6         |         0.0         |         0.0          |   2.8   |
# |   9   |        0.025        |         0.15        | 0.04285714285714286  |   4.0   |
# |   10  |         0.4         |         0.0         |         0.0          |   3.2   |
# |   11  |         0.4         |         0.18        |         0.18         |   3.6   |
# |   12  |         1.0         |         0.0         |         0.0          |   3.6   |
# |   13  | 0.18205128205128202 |         0.38        | 0.22317603964662788  |   4.4   |
# |   14  |         0.2         |         0.0         |         0.0          |   3.6   |
# |   15  | 0.41666666666666663 | 0.06666666666666667 | 0.026666666666666665 |   4.0   |
# |   16  | 0.23443223443223443 |  0.4066666666666666 |  0.2951226551226551  |   4.0   |
# +-------+---------------------+---------------------+----------------------+---------+
# Average metrics saved to OWNDATASET_AFTERKFOLD.xlsx

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# # Create an ImageDataGenerator object
# datagen = ImageDataGenerator(rescale=1./255)

# # Create a generator
# generator = datagen.flow_from_directory(
#     'D:\\New Dataset Lip Movement Projec\\FINAL YEAR PROJECT\\output_denoised_image_folder',
#     target_size=(150, 150),
#     batch_size=16,
#     class_mode='binary'
# )

# print(generator.batch_size)
# Out:
# Found 298 images belonging to 17 classes.
# 16
